# %% [markdown]
# # Quiz 4
#
# <font size='4'>
#
# BIOS-584<br>
# Nov 21, 2025
#
# * Write down your name in a Markdown section.

# %% [markdown]
# yuchen gong

# %%
import numpy as np
import pandas as pd
import os

# %% [markdown]
# ## Preliminary
#
# <font size='4'>
#
# * There are six files stored under `Your own GitHub repository/data/Quiz4`.
# * Import those six files using relevant functions in `Pandas`.

# %%
print(os.getcwd())
df1 = pd.read_csv('{}/data/Quiz4/data_1.txt'.format(os.getcwd()), sep=',')
df2 = pd.read_csv('{}/data/Quiz4/data_2.txt'.format(os.getcwd()), sep=',')
df3 = pd.read_csv('{}/data/Quiz4/data_3.txt'.format(os.getcwd()), sep=',')
df4 = pd.read_csv('{}/data/Quiz4/data_4.txt'.format(os.getcwd()), sep=',')
df5 = pd.read_csv('{}/data/Quiz4/data_5.txt'.format(os.getcwd()), sep=',')
df6 = pd.read_csv('{}/data/Quiz4/data_6.txt'.format(os.getcwd()), sep=',')
print(df1)
print(df2)
print(df3)
print(df4)
print(df5)
print(df6)
# Out:
# /Users/yuchen/Documents/GitHub/BIOS-584
#    study_id measure_date  duration
# 0         1   2025-01-01       100
#    study_id measure_date  duration
# 0         1   2025-03-01       300
#    study_id measure_date  duration
# 0         1   2025-02-01       200
#    study_id measure_date  duration
# 0         1   2025-11-01        25
#    study_id measure_date  duration
# 0         1   2025-11-01        20
#    study_id measure_date  duration
# 0         1   2025-11-03        30

# %% [markdown]
# ## Import Data
#
# <font size='4'>
#
# * Three lists named `study_id_ls`, `measure_date_ls`, and `duration_ls` have been initialized.
# * Write a for loop to extract and append the values of `study_id`, `measure_date`, and `duration` to `study_id_ls`, `measure_date_ls`, and `duration_ls`, respectively.

# %%
study_id_ls = []
measure_date_ls = []
duration_ls = []
for df in df_list:
    for idx, row in df.iterrows():
        study_id_ls.append(row["study_id"])
        measure_date_ls.append(row["measure_date"])
        duration_ls.append(row["duration"])

# %% [markdown]
# <font size='4'>
#
# * Create a new Pandas Dataframe combining three lists and name it `input_df`.

# %%
input_df = pd.DataFrame({"study_id": study_id_ls,
    "measure_date": measure_date_ls,
    "duration": duration_ls})

# %% [markdown]
# <font size='4'>
#
# * Show or print `input_df`

# %%
print(input_df)
# Out:
#    study_id measure_date  duration
# 0         1   2025-01-01       100
# 1         1   2025-03-01       300
# 2         1   2025-02-01       200
# 3         1   2025-11-01        25
# 4         1   2025-11-01        20
# 5         1   2025-11-03        30

# %% [markdown]
# ## Data Manipulation
#
# <font size='4'>
#
# * Reorder the dataframe by `measure_date` (earliest to latest) and then by `duration` (shortest to longest).

# %%
input_df.sort_values(
    by=["measure_date", "duration"],
    ascending=[True, True],
    inplace=True)
print(input_df)
# Out:
#    study_id measure_date  duration  relative_time
# 0         1   2025-01-01       100              0
# 1         1   2025-02-01       200             31
# 2         1   2025-03-01       300             59
# 3         1   2025-11-01        20            304
# 4         1   2025-11-01        25            304
# 5         1   2025-11-03        30            306

# %% [markdown]
# <font size='4'>
#
# * Create a new column called `relative_time` by calculating the time difference in days between each of the measure date and the earliest one.

# %%
input_df["measure_date"] = pd.to_datetime(input_df["measure_date"])
earliest_date = input_df["measure_date"].min()
input_df["relative_time"] = (input_df["measure_date"] - earliest_date).dt.days

# %% [markdown]
# <font size='4'>
#
# * Reset the index column and remove the old index.

# %%
input_df = input_df.reset_index(drop=True)

# %% [markdown]
# ## Final Data Visualization
# <font size='4'>
#
# * Display the final `input_df`.

# %%
print(input_df)
# Out:
#    study_id measure_date  duration  relative_time
# 0         1   2025-01-01       100              0
# 1         1   2025-02-01       200             31
# 2         1   2025-03-01       300             59
# 3         1   2025-11-01        20            304
# 4         1   2025-11-01        25            304
# 5         1   2025-11-03        30            306
